# %%
# activate R magic
# %load_ext rpy2.ipython
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %%R
# library(ggplot2)

# %%
# %%R
# data("diamonds")

# %%
# %%R
# qplot(x = price, data = diamonds)
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# qplot(x = price, y = carat, data = diamonds)

# %%
# %%R
# qplot(x = cut, y = carat, data = diamonds)

# %%
# %%R
# v <- diamonds$carat
# qplot(v)
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# Используя функцию qplot, постройте гистограмму переменной depth из данных diamonds. Сохраните график в переменную depth_hist.
# ![](https://ucarecdn.com/f51422e5-942e-4051-9267-8177f7e2aff5/)

# %%
# %%R
# qplot(diamonds$depth)
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# qplot(x = price,
#       y = carat,
#       color = color,
#       data = diamonds)

# %%
# %%R
# qplot(mpg,
#       hp,
#       color = factor(am),
#       shape = factor(cyl),
#       data = mtcars)

# %%
# %%R
# qplot(mpg,
#       hp,
#       color = factor(am),
#       shape = factor(cyl),
#       size = I(5),
#       data = mtcars)

# %%
# %%R
# qplot(mpg,
#       hp,
#       color = "green",
#       size = I(5),
#       shape = factor(cyl),
#       data = mtcars)

# %%
# %%R
# qplot(mpg,
#       hp,
#       color = I("green"),
#       size = I(5),
#       shape = factor(cyl),
#       data = mtcars)

# %% [markdown]
# Теперь давайте отобразим сразу три переменные на одном графике!
#
# Постройте диаграмму рассеивания (scatter plot) как в указанном ниже примере, результат сохраните в переменную price_carat_clarity_points.
#
# - данные - diamonds
# - ось x - carat
# - ось y - price
# - цвет точек - clarity
# ![](https://ucarecdn.com/1dee4e9d-b8fc-49ef-bb14-a28a4c7604a5/)

# %%
# %%R
# qplot(x = carat,
#       y = price,
#       color = factor(clarity),
#       data = diamonds)

# %%
# %%R
# qplot(mpg,
#       hp,
#       color = I("blue"),
#       shape = factor(cyl),
#       size = I(5),
#       alpha = I(0.3),
#       data = mtcars)

# %%
# %%R
# qplot(x = price, data = diamonds, fill = I("white"))
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# qplot(x = price, data = diamonds, fill = I("white"), col = I("black"))
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# qplot(x = price, data = diamonds, fill = color, col = I("black"))
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# qplot(x = price,
#       data = diamonds,
#       fill = color,
#       col = I("black"),
#       geom= "density")

# %%
# %%R
# qplot(x = price,
#       data = diamonds,
#       fill = color,
#       col = I("black"),
#       alpha = I(0.2),
#       geom = "density")

# %% [markdown]
# Используя функцию qplot, постройте график плотности переменной x из данных diamonds. Сохраните график в переменную x_density.
# ![](https://ucarecdn.com/6108871e-8043-4613-9ace-58eb38d635d4/)

# %%
# %%R
# qplot(x,
#       data = diamonds,
#       col = I("black"),
#       geom = "density")

# %% [markdown]
# Усложним задачу, постройте график плотности переменной x для каждой группы наблюдений по переменной cut из данных diamonds. Таким образом за цвет графика теперь отвечает переменная cut. Сохраните результат в переменную x_cut_density.
# ![](https://ucarecdn.com/418f715f-0b5a-45e2-bc5e-99b4c2f91aff/)

# %%
# %%R
# qplot(x,
#       data = diamonds,
#       col = factor(cut),
#       geom = "density")

# %% [markdown]
# Давайте знакомиться с различными geoms. Документация пакета и весь список с примерами использования доступен [здесь](https://ggplot2.tidyverse.org/reference/). Вообще обратите внимание на документацию ggplot2, очень подробное описание основных возможностей пакета!
#
# Давайте построим график violin plot для переменной price в каждой группе наблюдений по переменной color. Сохраните результа в переменную price_violin.
# ![](https://ucarecdn.com/94926940-6047-4407-9a81-70d0bd1b5491/)

# %%
# %%R
# qplot(x = color,
#       y = price,
#       data = diamonds,
#       geom = "violin")
