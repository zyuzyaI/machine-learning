# %% [markdown]
# ## step 2

# %% [markdown]
# Скопируйте содержимое файла /home/box/condition в /home/box/answer

# %% [markdown]
# ```
# cp /home/box/condition /home/box/answer
# ```

# %% [markdown]
# ## step 4

# %% [markdown]
# Используя инструкцию из предыдущего шага скопируйте текст
# ```
# NDQxNzU3NWRlMzYwYzFlODk3ZDU1NzlmYjQ1MjM4YTZjNjJjZTcyZDEwYTY5ODE1Yjg2MmUZTMwM2MxYTgyZCAgLQo
# ```
# в файл /home/box/answer .

# %% [markdown]
# ## step 6

# %% [markdown]
# ```
# vim /home/box/answer
# ```

# %% [markdown]
# Скопируйте содержимое файла /home/box/for_next_task из предыдущего задания в поле ниже.
#
# Подсказка: если вы уже решили предыдущее задание то для того, чтобы еще раз открыть терминал,  нажмите Попробовать снова.

# %% [markdown]
# ```
# vim /home/box/for_next_task
# # mVQOaZMZmAuCQ9ng1RurSlVT1bBjDgarW5AULZeBNtU
# ```
