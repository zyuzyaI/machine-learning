# %%
# %load_ext rpy2.ipython
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %% [markdown]
# 1. Обрахуйте медіану для ряду: 5, 2, 2, 8, 6, 43.
#
# - [ ] 11
# - [x] 5.5
# - [ ] 6
# - [ ] 4

# %%
# %%R
# median(c(5, 2, 2, 8, 6, 43))
# Out:
# [1] 5.5

# %% [markdown]
# 2. Обрахуйте середнє значення для ряду: 5, 2, 2, 8, 6, 43.
#
# - [x] 11
# - [ ] 5.5
# - [ ] 6
# - [ ] 4

# %%
# %%R
# mean(c(5, 2, 2, 8, 6, 43))
# Out:
# [1] 11

# %% [markdown]
# 3. Ймовірність може набирати значень в інтервалі:
#
# - [ ] [-10, 10]
# - [ ] [0, 10]
# - [ ] [-1, 1]
# - [x] [0, 1]

# %% [markdown]
# 4. В коробці є 8 чорних куль та 6 білих. Випадковим чином дістали одну кулю. Яка ймовірність, що ця куля біла?
#
# - [ ] 4/7
# - [ ] 1/14
# - [x] 3/7
# - [ ] 1/6

# %% [markdown]
# 5. Якщо ви підкидаєте монету 10 разів, яка ймовірність отримати 4 решки? (Вважаємо, що монета чесна і ймовірність випадання решки 50%)
#
# - [ ] 50%
# - [ ] 40%
# - [x] 21%
# - [ ] 62%

# %%
210 * 0.5**4 * 0.5**6
# Out:
# 0.205078125

# %% [markdown]
# 6. Скільки мод має нормальний розподіл:
#
# - [ ] дві
# - [ ] безліч
# - [x] одну
# - [ ] жодної

# %% [markdown]
# 7. Середньоквадратичне відхилення вибіркового розподілу зменшується:
#
# - [ ] при збільшенні середньоквадратичного відхилення вибірки
# - [x] при збільшенні розміру вибірки
# - [ ] при зменшенні розміру вибірки
# - [ ] при збільшенні середньоквадратичного середнього значення вибірки

# %% [markdown]
# 8. Якщо довірчий інтервал з рівнем довіри 95% не містить значення нульової гіпотези, то:
#
# - [ ] p-value більше α=0.1
# - [x] p-value менше α=0.05
# - [ ] p-value менше α=0.01

# %% [markdown]
# 9. Виробник іграшок стверджує, що відсоток іграшок з дефектом становить 3%. Для перевірки якості обрали 100 іграшок. Яка ймовірність що 3 з них мають дефект?
#
# - [ ] 3%
# - [x] 22.7%
# - [ ] 30%
# - [ ] 33.3%

# %%
# %%R
# 1.96 * (0.03*(1-0.03)/ 100)**0.5
# Out:
# [1] 0.5133362

# %% [markdown]
# 10. Час життя батарейок нормально розподілений. Середнє значення цього розподілу 500 днів, середньоквадратичне відхилення 61 день. Який відсоток батарейок прослужить довше ніж 580 днів?
#
# - [ ] 33%
# - [x] 9%
# - [ ] 90%
# - [ ] 68%

# %%
# %%R
# pnorm((580 - 500)/61, lower.tail=FALSE)
# Out:
# [1] 0.0948486

# %% [markdown]
# 11. Значення коефіцієнта кореляції Пірсона -2 говорить про:
#
# - [ ] сильний негативний лінійний зв'язок
# - [x] помилку в обчисленні
# - [ ] відсутність кореляції
# - [ ] сильний позитивний лінійний зв'язок

# %% [markdown]
# 12. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу.
# Гіпотези: Ho:μ=0.69,Ha:μ≠0.69
#
# α=0.05
#
# Знайдіть середньоквадратичне відхилення вибіркового розподілу.
#
# - [ ] 0.123
# - [ ] 0.023
# - [x] 0.038
# - [ ] 0.256

# %%
# %%R
# se <-  (0.69*(1-0.69)/150)**0.5
# print(se)
# Out:
# [1] 0.03776242

# %% [markdown]
# 13. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу.
# Гіпотези: Ho:μ=0.69,Ha:μ≠0.69
#
# α=0.05
#
# Знайдіть тестову статистику.
#
# - [ ] -1.23
# - [ ] 0.97
# - [x] -0.97
# - [ ] 2.34

# %%
# %%R
# ((98/150)-0.69) / (0.69*(1-0.69)/150)**0.5
# Out:
# [1] -0.9709831

# %% [markdown]
# 14. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу.
# Гіпотези: Ho:μ=0.69,Ha:μ≠0.69
#
# α=0.05
#
# Знайдіть p-value.
#
# - [ ] 0.13
# - [ ] 0.63
# - [x] 0.33
# - [ ] 0.35

# %%
# %%R
# z <- ((98/150 - 0.69)/ (0.69*(1-0.69)/150)**0.5)
# 2 * pnorm(z)
# Out:
# [1] 0.3315567

# %% [markdown]
# 15. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу.
# Гіпотези: Ho:μ=0.69,Ha:μ≠0.69
#
# α=0.05
#
# Чи можна відхилити нульову гіпотезу на основі вказаної в умові вибірки?
#
# - [ ] так
# - [x] ні
# - [ ] недостатньо даних

# %% [markdown]
# 16. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу.
# Гіпотези: Ho:μ=0.69,Ha:μ≠0.69
#
# α=0.05
#
# Чи можна вважати, що відсоток жителів з надлишковою вагою в цьому місті статистично відрізняється від загальнонаціонального для США?
#
# - [ ] так
# - [x] ні
# - [ ] недостатньо даних

# %% [markdown]
# 17. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу. Знайдіть межу похибки (margin of error) для довірчого інтервалу з рівнем надійності 99%.
#
# - [x] 10%
# - [ ] 15%
# - [ ] 21%
# - [ ] 18%

# %%
# %%R
# z <- ((0.69*(1-0.69)/150)**0.5)
# z * 2.58
# Out:
# [1] 0.09742703

# %% [markdown]
# 18. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу. Знайдіть розмір вибірки n для якого межа похибки (margin of error) не перевищує 5% (для довірчого інтервалу з рівнем надійності 99%)
#
# - [ ] 354
# - [x] 570
# - [ ] 520
# - [ ] 200

# %%
# %%R
# (2.58 / 0.05)**2 * 0.69 *(1-0.69)
# Out:
# [1] 569.5216

# %% [markdown]
# 19. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу. Знайдіть довірчий інтервал для рівня надійності 90%.
#
# - [ ] [51.2, 69.3]
# - [ ] [74.1, 76.3]
# - [x] [58.7, 71.4]
# - [ ] [65.2, 86.3]

# %%
# %%R
# print(0.69 - 1.64 * (0.69*(1-0.69)/150)**0.5)
# print( 0.69 + 1.64 * (0.69*(1-0.69)/150)**0.5)
# Out:
# [1] 0.6280696
# [1] 0.7519304

# %% [markdown]
# 20. Згідно даних організації CDC (Center for Disease Control) 69% дорослих віком від 20 років мають надлишкову вагу. Мер невеликого міста вирішив визначити, чи відрізняється цей відсоток у його місті. Випадковим чином було обрано 150 дорослих віком від 20 років. 98 з них мають надлишкову вагу. Чи містить довірчий інтервал з рівнем надійності 90% значення нульової гіпотези?
#
# - [ ] ні
# - [x] так
